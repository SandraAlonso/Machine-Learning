# %% [markdown]
# # Análisis y estudio de los datos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ## Lectura de datos

# %%
path ='dataset18.csv'
data = pd.read_csv(path)
data.head(5)
# Out:
#    Unnamed: 0 Target  n_rs3188513  n_rs9960669  n_rs2602  n_rs5445365  \
# 0           0      R            0            2         2            1
# 1           1      R            1            2         1            2
# 2           2      R            1            0         2            1
# 3           3      R            0            2         2            1
# 4           4      R            2            1         2            0
#
#    n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  ...  n_rs9280789  \
# 0           0             0            1            1  ...            0
# 1           0             2            0            2  ...            2
# 2           0             0            0            1  ...            2
# 3           0             2            1            0  ...            2
# 4           1             2            0            0  ...            1
#
#    n_rs2515462  n_rs9025039  n_rs94282819  n_rs344903  n_rs0370  n_rs9072249  \
# ...

# %% [markdown]
# ## Nombres de las columnas

# %%
print (data.columns)
# Out:
# Index(['Unnamed: 0', 'Target', 'n_rs3188513', 'n_rs9960669', 'n_rs2602',
#        'n_rs5445365', 'n_rs133061', 'n_rs10102851', 'n_rs8375668',
#        'n_rs3015353', 'n_rs3229523', 'n_rs6236416', 'n_rs5274755',
#        'n_rs9280789', 'n_rs2515462', 'n_rs9025039', 'n_rs94282819',
#        'n_rs344903', 'n_rs0370', 'n_rs9072249', 'n_rs0220', 'n_rs833068',
#        'n_rs933069'],
#       dtype='object')

# %% [markdown]
# ## Descripción de los datos:
# 1. Tamaño (shape)
# 2. Número de elementos (count)
# 3. Desviación estandar (std)
# 4. Valor mínimo (min)
# 5. Percentil bajo (25%)
# 6. Mediana (50%)
# 7. Percentil alto (75%)
# 8. Valor máximo (max)

# %%
print('The shape of our data is:', data.shape)
data.describe()
# Out:
# The shape of our data is: (53, 23)
#        Unnamed: 0  n_rs3188513  n_rs9960669   n_rs2602  n_rs5445365  \
# count   53.000000    53.000000     53.00000  53.000000    53.000000
# mean    26.000000     0.754717      1.45283   1.415094     1.339623
# std     15.443445     0.782148      0.79822   0.691541     0.807260
# min      0.000000     0.000000      0.00000   0.000000     0.000000
# 25%     13.000000     0.000000      1.00000   1.000000     1.000000
# 50%     26.000000     1.000000      2.00000   2.000000     2.000000
# 75%     39.000000     1.000000      2.00000   2.000000     2.000000
# max     52.000000     2.000000      2.00000   2.000000     2.000000
#
#        n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  n_rs3229523  ...  \
# count   53.000000     53.000000    53.000000    53.000000    53.000000  ...
# mean     0.811321      1.490566     0.716981     1.094340     0.641509  ...
# std      0.833358      0.823282     0.885293     0.925372     0.810848  ...
# ...

# %% [markdown]
# ## Descripcción de la columna objetivo

# %%
print(data.Target.value_counts())
# Out:
# R     30
# NR    23
# Name: Target, dtype: int64

# %%
# Historgrama con la cantidad de R y NR de data
sns.countplot(x=data.Target, data=data, palette='hls')
plt.show()

# %%
# Media de cada uno de los atributos
print(data.groupby(data.Target).mean())
# Out:
#         Unnamed: 0  n_rs3188513  n_rs9960669  n_rs2602  n_rs5445365  \
# Target
# NR       34.521739     1.130435     1.695652  1.521739     1.565217
# R        19.466667     0.466667     1.266667  1.333333     1.166667
#
#         n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  n_rs3229523  ...  \
# Target                                                                   ...
# NR        1.173913      1.826087     1.043478     1.217391     0.739130  ...
# R         0.533333      1.233333     0.466667     1.000000     0.566667  ...
#
#         n_rs9280789  n_rs2515462  n_rs9025039  n_rs94282819  n_rs344903  \
# Target
# NR         1.608696     0.869565     1.826087      1.739130    1.869565
# R          1.000000     0.366667     1.200000      1.333333    1.233333
#
#         n_rs0370  n_rs9072249  n_rs0220  n_rs833068  n_rs933069
# Target
# NR      1.478261     1.347826  1.043478    1.086957     1.26087
# R       1.233333     1.033333  0.633333    1.000000     0.90000
#
# ...

# %% [markdown]
# ### Observaciones:
# La media de los valores de los datos de NR son significativamente mayores

# %% [markdown]
#  ## Análisis de componentes principales (APC)

# %%
X = data.iloc[:,2:23] #Seleccionamos todas las columnas quitando la columna Unnamed (id de la fila ) y la columna Target.
pca = PCA(n_components=21)
pca.fit(X)
# En este array se muestra el porcentaje de variación de cada uno de los componentes.
# Como podemos obseverar no hay apenas variación.
print(pca.explained_variance_ratio_)
# Out:
# [0.13701915 0.11650416 0.09384087 0.0844153  0.06877811 0.06452416
#  0.05639792 0.05484624 0.04454132 0.04216202 0.0387468  0.03343159
#  0.03051018 0.02719898 0.02586916 0.02127236 0.01913035 0.01456861
#  0.01113887 0.00860135 0.00650252]
